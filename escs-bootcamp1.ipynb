# %%
x = 5
print(x)

print('Hello, world!')
# Out:
# 5
# Hello, world!

# %%
x = 2 + 3

x = 2 * 3

x = 2 ** 3

# Kako koristimo /, //, % ?

# %%
y = 'Python'

# z = x + y 
# print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 y = 'Python'
# ----> 3 z = x + y
#       4 print(z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
list_of_numbers = [1, 2, 3, 4, 5, 6]
print(list_of_numbers[0]) # probaj i list_of_numbers[6]

empty_list = list() # ili []

for i in range(1, 21):
    empty_list.append(i)
# Out:
# 1

# %%
print(dir(list_of_numbers))

list_of_numbers.append(7)

# print(list_of_numbers)
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
suma = 0 

for i in range(len(list_of_numbers)): 
    suma += list_of_numbers[i]
    print('Vrednost zbira je sada: ', suma)
# Out:
# Vrednost zbira je sada:  1
# Vrednost zbira je sada:  3
# Vrednost zbira je sada:  6
# Vrednost zbira je sada:  10
# Vrednost zbira je sada:  15
# Vrednost zbira je sada:  21

# %%
def sabiranje(x):
    
    suma = 0
    
    for i in range(len(x)): 
        suma += x[i]
    
    return suma 

sabiranje(list_of_numbers)
# Out:
# 21

# %%
sum(list_of_numbers)
max(list_of_numbers)
min(list_of_numbers)
len(list_of_numbers)
# Out:
# 6

# %%
import math as m
print(dir(m))

# %%
import random
dir(random)

random_numbers = [random.randint(1,100) for i in range(10)]
print(random_numbers)
# Out:
# [79, 90, 67, 72, 67, 77, 49, 14, 71, 32]

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import emoji

print(emoji.emojize(':sunflower:'))
print(emoji.emojize(':blue_heart:'))
print(emoji.emojize(':lion:'))
print(emoji.emojize(':cherries:'))
print(emoji.demojize('👩‍💻'))

# Link: https://www.webfx.com/tools/emoji-cheat-sheet/
# Out:
# 🌻
# 💙
# 🦁
# 🍒
# :woman_technologist:

# %% [markdown]
# **Prva Monte Karlo Simulacija**

# %% [markdown]
# Pretpostavićemo da smo u takmičenju i da nam je dat izbor između tri vrata, gde se iza jednih nalazi automobil kao nagrada u ovom takmičenju. Na nama je da izaberemo vrata. Pretpostavimo da smo odabrali vrata broj 1, a domaćin, koji zna šta se nalazi iza svaki vrata, otvara vrata iza kojih se ne nalazi nagrada (na primer, vrata broj 3). Nakon toga, daje nam izbor: **"Da li želite da promenite svoj izbor i izaberete vrata broj 2?"**. Želimo da otkrijemo šta bi bilo pametnije za nas - da ostanemo pri inicijalnom izboru ili da ga promenimo.
#
# Ukoliko fiksiramo izbor igrača (izbor je pao na Vrata 1) i posmatramo različite strategije (menjaj/ ne menjaj),
#
# | Vrata 1 | Vrata 2 |Vrata 3 | Osvajamo, ukoliko ostanemo | Osvajamo, ukoliko promenimo |
# | --- | --- | --- | --- | --- |
# | Auto | Koza | Koza | **Auto** | Koza |
# | Koza | Auto | Koza | Koza | **Auto** |
# | Koza | Koza | Auto | Koza | **Auto** |

# %%
import random

def monte_karlo_simulacije(n):
    
    menjaj = 0
    ne_menjaj = 0
    
    for i in range(n):

        auto = random.randint(1,3)
        izbor1 = random.randint(1,3)
        if (izbor1 == auto): # Izabrali smo vrata iza kojih se nalazi nagrada. Uspeh smo definisali sa 1. 
            izabrana_vrata = 1 # Objašnjenje: Ukoliko ostanemo pri svom inicijalnom izboru, osvajamo kola.
            zamenska_vrata = 0 # Ukoliko se odlučimo za strategiju "menjaj", izgubićemo šansu za osvajanje nagrade. 
        else: # Izabrali smo "pogrešna" vrata.
            izabrana_vrata = 0 # Ukoliko odlučimo da ostanemo pri inicijalnom izboru, gubimo šansu za osvajanje nagrade.
            zamenska_vrata = 1 # Izabrali smo pogrešna vrata (još to ne znamo). Voditelj otvara druga vrata iza kojih se takođe ne nalazi nagrada.
            # Ukoliko se odlučimo da promenimo vrata, osvajamo nagradu.
        menjaj += zamenska_vrata
        ne_menjaj += izabrana_vrata

    return print("Verovatnoća pobede ukoliko se odlučimo da promenimo izbor ", menjaj / n,", dok je verovatnoća ukoliko ostanemo pri inicijalnom izboru duplo niža i jednaka",ne_menjaj/n)

monte_karlo_simulacije(10000)
# Out:
# Verovatnoća pobede ukoliko se odlučimo da promenimo izbor  0.6653 , dok je verovatnoća ukoliko ostanemo pri inicijalnom izboru duplo niža i jednaka 0.3347
